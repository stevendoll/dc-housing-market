# %%
import json
import pandas as pd
import datetime as dt
import requests
import lxml.html
from lxml import html
from lxml.html.clean import Cleaner
import re
# %matplotlib inline
from time import sleep
from random import randint
import csv
import matplotlib.pyplot as plt

# %%
# clean data
df = pd.read_csv('data/dc-property-sales-1.csv')
df = pd.concat([df, pd.read_csv('data/dc-property-sales-2.csv')])

df['sale_date'] = pd.to_datetime(df['sale_date'])
df['sale_price'] = df['sale_price'].str.replace('$','').str.replace(',','').replace('.00','0').astype(float)
df['square'] = df.square_suffix.str.extract('(\S*)\s', expand=False)
df['suffix'] = df.square_suffix.str.extract('(.{4})\s*$', expand=False)
df['address'] = df.address.str.lower()
df.fillna(value='', inplace=True)
# Out:
#                                 address  \
# 0    2600 pennsylvania av nw unit: 0201
# 1    2600 pennsylvania av nw unit: 0202
# 2    2600 pennsylvania av nw unit: 0203
# 3    2600 pennsylvania av nw unit: 0204
# 4    2600 pennsylvania av nw unit: 0301
# 5    2600 pennsylvania av nw unit: 0302
# 6    2600 pennsylvania av nw unit: 0303
# 7    2600 pennsylvania av nw unit: 0304
# 8    2600 pennsylvania av nw unit: 0401
# 9    2600 pennsylvania av nw unit: 0402
# 10   2600 pennsylvania av nw unit: 0403
# 11   2600 pennsylvania av nw unit: 0404
# 12   2600 pennsylvania av nw unit: 0501
# 13   2600 pennsylvania av nw unit: 0502
# 14   2600 pennsylvania av nw unit: 0502
# 15   2600 pennsylvania av nw unit: 0504
# 16   2600 pennsylvania av nw unit: 0601
# 17   2600 pennsylvania av nw unit: 0602
# 18   2600 pennsylvania av nw unit: 0603
# 19   2600 pennsylvania av nw unit: 0604
# 20   2600 pennsylvania av nw unit: 0701
# 21   2600 pennsylvania av nw unit: 0702
# 22   2600 pennsylvania av nw unit: 0703
# 23   2600 pennsylvania av nw unit: 0704
# 24   2600 pennsylvania av nw unit: 0801
# 25   2600 pennsylvania av nw unit: 0802
# 26   2600 pennsylvania av nw unit: 0803
# 27   2600 pennsylvania av nw unit: 0804
# 28   2600 pennsylvania av nw unit: 0cs1
# 29   2600 pennsylvania av nw unit: 0cs2
# ..                                  ...
# 167                  1840 ontario pl nw
# 168                  1838 ontario pl nw
# 169                  1832 ontario pl nw
# 170                   1777 lanier pl nw
# 171                  1882 ontario pl nw
# 172                  1878 ontario pl nw
# 173                  1890 ontario pl nw
# 174                  1888 ontario pl nw
# 175                  1886 ontario pl nw
# 176                  1824 ontario pl nw
# 177                  1820 ontario pl nw
# 178                  1858 ontario pl nw
# 179                  1856 ontario pl nw
# 180                  1854 ontario pl nw
# 181                  1812 ontario pl nw
# 182                  1810 ontario pl nw
# 183                  1830 ontario pl nw
# 184                  1828 ontario pl nw
# 185                  1826 ontario pl nw
# 186                  1818 ontario pl nw
# 187                  1816 ontario pl nw
# 188                  1814 ontario pl nw
# 189                   1745 lanier pl nw
# 190                   1747 lanier pl nw
# 191                   1749 lanier pl nw
# 192                   1751 lanier pl nw
# 193                   1755 lanier pl nw
# 194                   1761 lanier pl nw
# 195                  2800 ontario rd nw
# 196                   1771 lanier pl nw
#
#                                            listing_url    neighborhood  \
# 0    https://www.taxpayerservicecenter.com/RP_Detai...    FOGGY BOTTOM
#
# 177  2583    0396               B        11   2583   0396
# 178  2583    0397               B        11   2583   0397
# 179  2583    0398               B        24   2583   0398
# 180  2583    0399               B        24   2583   0399
# 181  2583    0414               B        11   2583   0414
# 182  2583    0415               B        11   2583   0415
# 183  2583    0437               B        24   2583   0437
# 184  2583    0438               B        11   2583   0438
# 185  2583    0439               B        11   2583   0439
# 186  2583    0450               B        11   2583   0450
# 187  2583    0451               B        11   2583   0451
# 188  2583    0452               B        11   2583   0452
# 189  2583    0454               B        24   2583   0454
# 190  2583    0455               B        24   2583   0455
# 191  2583    0456               B        24   2583   0456
# 192  2583    0457               B        11   2583   0457
# 193  2583    0459               B        24   2583   0459
# 194  2583    0462               B        11   2583   0462
# 195  2583    0463               B        22   2583   0463
# 196  2583    0487               B        13   2583   0487
#
# [136045 rows x 11 columns]

# %%
# create list for geocode

# bulk geocoding
# https://geocoding.geo.census.gov/geocoder/locations/addressbatch;jsessionid=RCr7kx_FMfiT-V8DoGSHv9DxhjxTfPqPsSUMi-aQT6n_sbRTcri5!1894070029?form

chunk_size = 10000
number_of_files = len(df) // chunk_size + 1

for i in range(number_of_files):
    
    df_addresses = df['address'][i*chunk_size:(i+1)*chunk_size]
    df_addresses['zip'] = ''
    df_addresses['city'] = 'Washington'
    df_addresses['state'] = 'DC'
    
    filename = '/data/address-export-for-bulk-latlong-' + str(i) + '.csv'
    
    df_addresses.to_csv(filename)

# %%
# get geocode and merge
df_zip = pd.read_csv('data/GeocodeResults.csv', header=None, names=('address','match','match_type','address_geocode','latitude','longitude','lr'))
# df_zip = pd.concat([df_zip, pd.read_csv('data/GeocodeResults-1.csv')])
df_zip.address = df_zip.address.str.replace(', Washington, DC, ','')

df = df.merge(df_zip[df_zip.match == 'Match'][['address','address_geocode','latitude','longitude']], how='left', on='address')

df
# Out:
#                                    address  \
# 0       2600 pennsylvania av nw unit: 0201
# 1       2600 pennsylvania av nw unit: 0202
# 2       2600 pennsylvania av nw unit: 0203
# 3       2600 pennsylvania av nw unit: 0204
# 4       2600 pennsylvania av nw unit: 0301
# 5       2600 pennsylvania av nw unit: 0302
# 6       2600 pennsylvania av nw unit: 0303
# 7       2600 pennsylvania av nw unit: 0304
# 8       2600 pennsylvania av nw unit: 0401
# 9       2600 pennsylvania av nw unit: 0402
# 10      2600 pennsylvania av nw unit: 0403
# 11      2600 pennsylvania av nw unit: 0404
# 12      2600 pennsylvania av nw unit: 0501
# 13      2600 pennsylvania av nw unit: 0502
# 14      2600 pennsylvania av nw unit: 0502
# 15      2600 pennsylvania av nw unit: 0504
# 16      2600 pennsylvania av nw unit: 0601
# 17      2600 pennsylvania av nw unit: 0602
# 18      2600 pennsylvania av nw unit: 0603
# 19      2600 pennsylvania av nw unit: 0604
# 20      2600 pennsylvania av nw unit: 0701
# 21      2600 pennsylvania av nw unit: 0702
# 22      2600 pennsylvania av nw unit: 0703
# 23      2600 pennsylvania av nw unit: 0704
# 24      2600 pennsylvania av nw unit: 0801
# 25      2600 pennsylvania av nw unit: 0802
# 26      2600 pennsylvania av nw unit: 0803
# 136214          NaN                                              NaN
#
#                 latitude_y  longitude_y
# 0                      NaN          NaN
# 1                      NaN          NaN
# 2                      NaN          NaN
# 3                      NaN          NaN
# 4                      NaN          NaN
# 5                      NaN          NaN
# 6                      NaN          NaN
# 7                      NaN          NaN
# 8                      NaN          NaN
# 9                      NaN          NaN
# 10                     NaN          NaN
# 11                     NaN          NaN
# 12                     NaN          NaN
# 13                     NaN          NaN
# 14                     NaN          NaN
# 15                     NaN          NaN
# 16                     NaN          NaN
# 17                     NaN          NaN
# 18                     NaN          NaN
# 19                     NaN          NaN
# 20                     NaN          NaN
# 21                     NaN          NaN
# 22      -77.05485,38.90416   76225047.0
# 23                     NaN          NaN
# 24                     NaN          NaN
# 25                     NaN          NaN
# 26                     NaN          NaN
# 27                     NaN          NaN
# 28                     NaN          NaN
# 29                     NaN          NaN
# ...                    ...          ...
# 136185                 NaN          NaN
# 136186                 NaN          NaN
# 136187                 NaN          NaN
# 136188                 NaN          NaN
# 136189                 NaN          NaN
# 136190                 NaN          NaN
# 136191                 NaN          NaN
# 136192                 NaN          NaN
# 136193                 NaN          NaN
# 136194                 NaN          NaN
# 136195                 NaN          NaN
# 136196                 NaN          NaN
# 136197                 NaN          NaN
# 136198                 NaN          NaN
# 136199                 NaN          NaN
# 136200                 NaN          NaN
# 136201                 NaN          NaN
# 136202                 NaN          NaN
# 136203                 NaN          NaN
# 136204                 NaN          NaN
# 136205                 NaN          NaN
# 136206                 NaN          NaN
# 136207                 NaN          NaN
# 136208                 NaN          NaN
# 136209                 NaN          NaN
# 136210                 NaN          NaN
# 136211                 NaN          NaN
# 136212                 NaN          NaN
# 136213                 NaN          NaN
# 136214                 NaN          NaN
#
# [136215 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136045 entries, 0 to 196
# Data columns (total 11 columns):
# address            136045 non-null object
# listing_url        136045 non-null object
# neighborhood       136045 non-null object
# owner              136045 non-null object
# sale_date          136045 non-null datetime64[ns]
# sale_price         136045 non-null float64
# square_suffix      136045 non-null object
# subneighborhood    136045 non-null object
# use_code           136045 non-null int64
# square             136045 non-null object
# suffix             136045 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 12.5+ MB
# 132120

# %%
df.neighborhood.value_counts()

# %%
df.use_code.value_counts()

# %%
residential = [1,2,3,11,12,13,15,16,17,19]
df[(df.use_code.isin(residential))].use_code.value_counts()
# Out:
# 11    31369
# 17    22939
# 16    19668
# 12    19443
# 13     9967
# 1        70
# 15       36
# 19       13
# Name: use_code, dtype: int64

# %%
df = df[((df.use_code.isin(residential)) & (df.sale_price < 2000000) & (df.sale_price > 1000))]

df.hist(bins=50, figsize=(20,15))
# save_fig("attribute_histogram_plots")
plt.show()

# %%
df.describe()
df.info()
df.sample(10000)[address].to_csv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75694 entries, 0 to 188
# Data columns (total 11 columns):
# address            75694 non-null object
# listing_url        75694 non-null object
# neighborhood       75694 non-null object
# owner              75694 non-null object
# sale_date          75694 non-null datetime64[ns]
# sale_price         75694 non-null float64
# square_suffix      75694 non-null object
# subneighborhood    75694 non-null object
# use_code           75694 non-null int64
# square             75694 non-null object
# suffix             75694 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 6.9+ MB

# %%
#df['sale_price'] = df['sale_price'].str.replace('$','').str.replace(',','').replace('.00','0').astype(float)
# df.sale_price.hist(bins=50)
# #df.use_code.unique()
#  #   5 12 21 32 34 38
# df.sale_price.max()
# missing 280 and 741
#df.sale_price.mean()
# residential = [1,2,3,11,12,13,15,16,17,19]

# #df.use_code.value_counts()
# df_res = df[(df.use_code.isin(residential))] #.shape
#df_res = df[((df.use_code.isin(residential)) & (df.sale_price > 0))] #.shape
# 100k rows
# df_res.groupby(['square', 'suffix'])['address'].first() #.max()
# # 77k with sale price

# #df_res.shape
# df_res.square_suffix.value_counts()

# #df['square'] = re.compile('(\d*)\s').df['square_suffix']
# # df[((df.owner.str.contains('DOLL')))]
# # df.suffix.unique()
# df.suffix.unique()
df[df.address.str.contains('kilbourne')]

# %%
def property_analysis(group):

    # for each property
#     group['square'] = group.square
#     group['suffix'] = group.suffix
    group['sales'] = group.suffix.count()
    group['min_sale_price'] = group.sale_price.min()
    group['max_sale_price'] = group.sale_price.max()
    group['mean_sale_price'] = group.sale_price.mean()
    group['min_sale_date'] = group.sale_date.min()
    group['max_sale_date'] = group.sale_date.max()

    return group[0:1]

# cols = ['neighborhood', 'sales','min_sale_price','max_sale_price','min_sale_date','max_sale_date']

df_sales = df[df.sale_price > 0].sample(10000).groupby(['neighborhood']).apply(property_analysis) #[cols] 

# remove multilevel index
# df_sales.index = df_sales.index.droplevel(2)
# df_sales.index = df_sales.index.droplevel(1)
# df_sales.index.name = None
df_sales.sort_values('sales', ascending=False)

# %%
df = df.copy()
df['year'], df['month'] = df['sale_date'].apply(lambda x: x.year), df['sale_date'].apply(lambda x: x.month)

df['sales_counts'] = df.groupby('neighborhood')['month'].transform('count')

df_year = df.groupby(['year','neighborhood']).mean().reset_index()

def analyze_price(group):
    
    first_year_with_price = group.year.min()
    starting_price = group[group.year == first_year_with_price].sale_price.min()
    
    group['relative_price'] = group.sale_price / starting_price
    
    return group

df_year = df_year.groupby('neighborhood').apply(analyze_price)

fig, ax = plt.subplots(figsize=(20,15))

for key, grp in df_year.groupby(['neighborhood']):
    ax = grp.plot(ax=ax, kind='line', x='year', y='sale_price', label=key)

plt.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,15))

for key, grp in df_year[df_year.sales_counts > 2000].groupby(['neighborhood']):
    ax = grp.plot(ax=ax, kind='line', x='year', y='relative_price', label=key)

plt.legend(loc='best')
plt.show()

# %%
df_year[df_year.sales_counts > 2000]

# %%
df_year

# %%
def year_analysis(group):

    # for each donor, get first and last donation
    group['donor_name'] = group.last_name
    group['year_donations'] = group.amount.sum()
    group['total_donations'] = df[df.donor_id == group.donor_id.tolist()[0]].amount.sum()
    group['year'] = group.name[0] 

    return group[0:1]

cols = ['donor_id','donor_name','year','year_donations', 'total_donations']

df_year = df.groupby((df['donation_date'].map(lambda x: x.year), df.donor_id)).apply(year_analysis)[cols] #.sort_values('amount', ascending=False).index.values[0:1].tolist()[0]

# remove multilevel index
df_year.index = df_year.index.droplevel(2)
df_year.index = df_year.index.droplevel(1)
df_year.index.name = None

# %%
sales.sale_price.hist()
